# %%
print("hello")
# Out:
# hello

# %%
print("welcome")
# Out:
# welcome

# %%
a=0.5
b=0.6
c= a+b  
print(c)
print(type(c))
# Out:
# 1.1
# <class 'float'>

# %%
a = "hello world"
b="welcome"
print(a)
print(b)
print(type(a))
print(type(b))
print(a[1:5])
print(b[-5:])
# Out:
# hello world
# welcome
# <class 'str'>
# <class 'str'>
# ello
# lcome

# %%
a=[1,2,3]
b=[4,5,6]
print(a+b)
b[2]=9
print(b)
print(type(a))
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 9]
# <class 'list'>

# %%
fruits=["apple","banana","grapee","orange"]
fruits.append("blackcurrent")
print(fruits)
# Out:
# ['apple', 'banana', 'grapee', 'orange', 'blackcurrent']

# %%
fruits=["apple","banana","grapee","orange"]
fruits.clear()
print(fruits)
# Out:
# []

# %%
fruits=["apple","banana","grapee","orange"]
a=[1,22,11,33]
fruits.extend(a)
print(fruits)
# Out:
# ['apple', 'banana', 'grapee', 'orange', 1, 22, 11, 33]

# %%
fruits=["apple","banana","grapee","orange"]
z= fruits.copy()
print(z)
# Out:
# ['apple', 'banana', 'grapee', 'orange']

# %%
fruits = ['apple', 'banana', 'cherry','cherry']

x = fruits.count("cherry")
print(x)
# Out:
# 2

# %%
#append
fruits=["apple","banana","cherry","grape"]
fruits.append("butterscotch")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'grape', 'butterscotch']

# %%
#clear  
fruits=["apple","banana","cherry","grape"]
fruits.clear()
print(fruits)
# Out:
# []

# %%
#copy
fruits=["apple","banana","cherry","grape"]
x=fruits.copy()
print(x)
# Out:
# ['apple', 'banana', 'cherry', 'grape']

# %%
#count
fruits=["apple","banana","cherry","grape","cherry"]
x=fruits.count("cherry")
print(x)
# Out:
# 2

# %%
#index
fruits=["apple","banana","cherry","grape"]
x=fruits.index("banana")
print(x)
# Out:
# 1

# %%
#insert
fruits=["apple","banana","cherry","grape"]
x=fruits.insert(0,"butterscotch")
print(x)
# Out:
# None

# %%
#pop
fruits=["apple","banana","cherry","grape"]
x=fruits.pop(2)
print(x)
# Out:
# cherry

# %%
#remove
fruits=["apple","banana","cherry","grape"]
fruits.remove("apple")
print(fruits)
# Out:
# ['banana', 'cherry', 'grape']

# %%
#reverse
fruits=["apple","banana","cherry","grape"]
fruits.reverse()
print(fruits)
# Out:
# ['grape', 'cherry', 'banana', 'apple']

# %%
#sort
fruits=["apple", "grape","banana","cherry","grape"]
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'grape', 'grape']

# %%
#tuple
fruits=("apple","banana","cherry","grape")
print(type(fruits))
print(fruits)
# Out:
# <class 'tuple'>
# ('apple', 'banana', 'cherry', 'grape')

# %%
#tuple slicing
fruits=("apple","banana","cherry","grape")
print(fruits[0:2])
# Out:
# ('apple', 'banana')

# %%
#tuple immutable
fruits=()"apple","banana","cherry","grape")
fruits[1]="helo"
print(fruits)
# Out:
#   Cell In[69], line 2
#     fruits=()"apple","banana","cherry","grape")
#                                               ^
# SyntaxError: unmatched ')'

# %%
#set
set={"set1","set2","set3"}
print(set)
print(type(set))
# Out:
# {'set2', 'set1', 'set3'}
# <class 'set'>

# %%
#len set
set={"set1","set2","set3"}
print(len(set))
print(type(set))
# Out:
# 3
# <class 'set'>

# %%
#datatypes
var_1=0O123
var_2=0x123
print(var_1)
print(var_2)
# Out:
# 83
# 291

# %%
set1={10,20,30.10,'jenny,true'}
set2={}
set3=set()
print(set1,set2)
print(type(set2))
print(type(set1))
print(type(set3))
# Out:
# {'jenny,true', 10, 20, 30.1} {}
# <class 'dict'>
# <class 'set'>
# <class 'set'>

# %%
#set
set1={10,20,30,40,50}
set1.discard(10)
print(set1)
# Out:
# {50, 20, 40, 30}

# %%
print(10+20)
# Out:
# 30
